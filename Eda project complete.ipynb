# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\singh\OneDrive\Documents\Scanned Documents\2021_registered_companies.csv')

# %%
data.head()
# Out:
#                             company_uid date_of_registration month_name  \
# 0  b928b473-d6d6-4b92-a63d-d262bf30c24b           19-01-2021     Jan-21
# 1  9696190f-7478-4d61-81f1-fc4eb08cce13           25-01-2021     Jan-21
# 2  59de4ca1-c15f-4d6d-8de3-03319793c884           14-01-2021     Jan-21
# 3  e28b4caa-b7f9-4faf-8bbe-b12028177417           25-01-2021     Jan-21
# 4  e1861c6f-c2a0-4a89-81e9-b39f11b1b6c6           19-01-2021     Jan-21
#
#              state            roc                   category    class  \
# 0        Telangana  RoC-Hyderabad  Company limited by Shares  Private
# 1       Tamil Nadu    RoC-Chennai  Company limited by Shares  Private
# 2      Maharashtra       RoC-Pune  Company limited by Shares   Public
# 3        Telangana  RoC-Hyderabad  Company limited by Shares  Private
# 4  Jammu & Kashmir      RoC-Jammu  Company limited by Shares  Private
#
#        company_type  authorized_capital  paidup_capital  activity_code  \
# ...

# %%
#Short Explaination about columns int the dataset

#Dataset consists fo all the registered companies in period of January -21 to April-21

#company_uid -> A unique id given to every comapany registered.

#date_of_registeration -> Date on which the company was registered.

#month_name -> Month on which the company was registered.

#State -> State in which the company was registered.

#roc -> The Registrar of Companies ( ROC ) is an office under the Ministry of Corporate Affairs (MCA), which is the body that deals with the administration of companies and Limited Liability Partnerships in India. Basically this column contains information about the city of ROC.

#Category -> Defines the Category of the company.

#class -> Defines class of a comapny.

#comapny_type -> define type of the comapny.

#activity_description -> Defines what business the comapny is into.

# %%
data.isnull().sum()
# Out:
# company_uid             0
# date_of_registration    0
# month_name              0
# state                   0
# roc                     0
# category                0
# class                   0
# company_type            0
# authorized_capital      0
# paidup_capital          0
# activity_code           0
# activity_description    0
# dtype: int64

# %% [markdown]
# As we can see that dataset has zero null values.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54894 entries, 0 to 54893
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   company_uid           54894 non-null  object
#  1   date_of_registration  54894 non-null  object
#  2   month_name            54894 non-null  object
#  3   state                 54894 non-null  object
#  4   roc                   54894 non-null  object
#  5   category              54894 non-null  object
#  6   class                 54894 non-null  object
#  7   company_type          54894 non-null  object
#  8   authorized_capital    54894 non-null  int64
#  9   paidup_capital        54894 non-null  int64
#  10  activity_code         54894 non-null  int64
#  11  activity_description  54894 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 5.0+ MB

# %%
data['authorized_capital'] = data['authorized_capital'].astype('int')
data['paidup_capital'] = data['paidup_capital'].astype('int')
data['activity_code'] = data['activity_code'].astype('int')

# %%
#Since date_of_registeration and activity code is of no use to our project we drop that column

data = data.drop(['date_of_registration','activity_code'], axis = 1)

# %%
data.head()
# Out:
#                             company_uid month_name            state  \
# 0  b928b473-d6d6-4b92-a63d-d262bf30c24b     Jan-21        Telangana
# 1  9696190f-7478-4d61-81f1-fc4eb08cce13     Jan-21       Tamil Nadu
# 2  59de4ca1-c15f-4d6d-8de3-03319793c884     Jan-21      Maharashtra
# 3  e28b4caa-b7f9-4faf-8bbe-b12028177417     Jan-21        Telangana
# 4  e1861c6f-c2a0-4a89-81e9-b39f11b1b6c6     Jan-21  Jammu & Kashmir
#
#              roc                   category    class      company_type  \
# 0  RoC-Hyderabad  Company limited by Shares  Private  Non-govt company
# 1    RoC-Chennai  Company limited by Shares  Private  Non-govt company
# 2       RoC-Pune  Company limited by Shares   Public  Non-govt company
# 3  RoC-Hyderabad  Company limited by Shares  Private  Non-govt company
# 4      RoC-Jammu  Company limited by Shares  Private  Non-govt company
#
#    authorized_capital  paidup_capital activity_description
# 0             1500000          102000         Construction
# ...

# %%
#Lets find out number of Companies registered in every month.

index = data.month_name.value_counts().keys().tolist()
counts = data.month_name.value_counts().tolist()

# %%
sns.barplot(index,counts)
plt.show()
# Out:
# D:\bin\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# From the above graph we can see that March 2021 has most number of companies registered and January 2021 has least companies registered.

# %%
data.state.unique()
# Out:
# array(['Telangana', 'Tamil Nadu', 'Maharashtra', 'Jammu & Kashmir',
#        'Karnataka', 'Uttar Pradesh', 'Delhi', 'Madhya Pradesh', 'Gujarat',
#        'Orissa', 'Rajasthan', 'Jharkhand', 'Bihar', 'Haryana', 'Kerala',
#        'Uttarakhand', 'West Bengal', 'Andhra Pradesh', 'Goa',
#        'Chattisgarh', 'Nagaland', 'Daman and Diu', 'Himachal Pradesh',
#        'Assam', 'Punjab', 'Chandigarh', 'Dadra & Nagar Haveli', 'Manipur',
#        'Andaman & Nicobar', 'Pondicherry', 'Tripura', 'Meghalaya',
#        'Lakshadweep', 'MH', 'TG', 'GJ', 'CH', 'DL', 'HR', 'UP', 'RJ',
#        'CT', 'KL', 'WB', 'KA', 'MP', 'PB', 'BR', 'MN', 'TN', 'OR', 'HP',
#        'UR', 'JH', 'AP', 'GA', 'AS', 'DN', 'TR', 'JK', 'PY', 'MZ', 'NL',
#        'AN', 'AR', 'LD', 'ML', 'LH', 'Arunachal Pradesh', 'Mizoram',
#        'Ladakh'], dtype=object)

# %% [markdown]
# First we will clean the state column

# %%
state_code ={'MH':  'Maharashtra','TG': 'Telangana','GJ': 'Gujarat','CH': 'Chandigarh'
             ,'DL': 'Delhi','HR': 'Haryana','UP': 'Uttar Pradesh','RJ': 'Rajasthan',
             'CT': 'Chattisgarh','KL': 'Kerala','WB': 'West Bengal','KA': 'Karnataka',
             'MP': 'Madhya Pradesh','PB': 'Punjab','BR': 'Bihar','MN': 'Manipur',
             'TN': 'Tamil Nadu','OR': 'Orissa','HP': 'Himachal Pradesh','UR': 'Uttarakhand',
             'JH': 'Jharkhand','AP': 'Andhra Pradesh','GA': 'Goa','AS': 'Assam',
             'DN': 'Dadra & Nagar Haveli','TR': 'Tripura','JK': 'Jammu & Kashmir','PY': 'Pondicherry',
             'MZ': 'Mizoram','NL': 'Nagaland','AN': 'Andaman & Nicobar','AR': 'Arunachal Pradesh',
             'LD': 'Lakshadweep','ML': 'Meghalaya','LH': 'Jammu & Kashmir','DD': 'Daman and Diu'
     }

# %%
data.replace({"state": state_code},inplace=True)

# %%
data.state.unique()
# Out:
# array(['Telangana', 'Tamil Nadu', 'Maharashtra', 'Jammu & Kashmir',
#        'Karnataka', 'Uttar Pradesh', 'Delhi', 'Madhya Pradesh', 'Gujarat',
#        'Orissa', 'Rajasthan', 'Jharkhand', 'Bihar', 'Haryana', 'Kerala',
#        'Uttarakhand', 'West Bengal', 'Andhra Pradesh', 'Goa',
#        'Chattisgarh', 'Nagaland', 'Daman and Diu', 'Himachal Pradesh',
#        'Assam', 'Punjab', 'Chandigarh', 'Dadra & Nagar Haveli', 'Manipur',
#        'Andaman & Nicobar', 'Pondicherry', 'Tripura', 'Meghalaya',
#        'Lakshadweep', 'Mizoram', 'Arunachal Pradesh', 'Ladakh'],
#       dtype=object)

# %% [markdown]
# Now we will find which state has most number of companies registered.

# %%
index = data.state.value_counts().keys().tolist()
counts = data.state.value_counts().tolist()

# %%
plt.figure(figsize= (20,10))

sns.barplot(index,counts)
plt.xticks(rotation = 90)
plt.show()
# Out:
# D:\bin\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print('No of companies registered in each state \n')
data.groupby(['state']).size().sort_values(ascending=False)
# Out:
# No of companies registered in each state
# state
# Maharashtra             10077
# Uttar Pradesh            5772
# Delhi                    5449
# Karnataka                4213
# Telangana                3655
# Tamil Nadu               3515
# Gujarat                  3057
# Haryana                  2705
# West Bengal              2551
# Kerala                   2084
# Bihar                    1997
# Rajasthan                1979
# Madhya Pradesh           1578
# Andhra Pradesh           1184
# Orissa                   1110
# Punjab                    771
# Jharkhand                 647
# Assam                     440
# Chattisgarh               437
# Uttarakhand               432
# Jammu & Kashmir           332
# Himachal Pradesh          244
# Chandigarh                220
# Goa                       153
# Manipur                    83
# Pondicherry                49
# Tripura                    39
# Arunachal Pradesh          23
# Nagaland                   21
# ...

# %% [markdown]
# We can see that Maharashtra has most number of companies registered.
#
# Taking closer look, now we will find states having less companies registered.

# %%
plt.figure(figsize= (20,10))

sns.barplot(index[-15:],counts[-15:])
plt.xticks(rotation = 90)
plt.show()
# Out:
# D:\bin\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# We can also find number of companies registered only in month of JANUARY.

# %%
registered_jan = data[data['month_name'] == 'Jan-21'].groupby(['state']).count()
state_index = registered_jan.index.tolist()
count_jan = registered_jan['company_uid'].tolist()

# %%
plt.figure(figsize= (20,10))

sns.barplot(state_index,count_jan)
plt.xticks(rotation = 90)
plt.show()
# Out:
# D:\bin\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# MAHARASHTRA tops with DELHI AT second position.
#
# Same we can do for month of FEBRUARY.

# %%
registered_feb = data[data['month_name'] == 'Feb-21'].groupby(['state']).count()
state_index = registered_feb.index.tolist()
count_feb= registered_feb['company_uid'].tolist()

# %%
plt.figure(figsize= (20,10))

sns.barplot(state_index,count_feb)
plt.xticks(rotation = 90)
plt.show()
# Out:
# D:\bin\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Lets check categories of companies.

# %%
data.category.unique()
# Out:
# array(['Company limited by Shares', 'Company Limited by Guarantee'],
#       dtype=object)

# %%
category = data.category.value_counts().keys().tolist()
counts = data.category.value_counts().tolist()

# %%
sns.barplot(category,counts)
plt.show()
# Out:
# D:\bin\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Company limited by shares: Nowadays, most of the companies are moving for Limited by Shares; this type is likely to be opted
# for commercial nature of business for profit making organization
#
# Company limited by guarantee: This type company is likely to be opted for non-profit businesses like community and
# charitable trust organizations
#
# We can see that company limited by share are more compare to limited by gurantee.

# %% [markdown]
# Now we will find companies in each sector.

# %%
ax=plt.figure(figsize=(11,8)).add_axes([0,0,1,1])
sns.set_style('white')
sns.countplot(y='activity_description',data=data)
for rect in ax.patches:
    ax.text (rect.get_width(), rect.get_y() + rect.get_height() / 2,
             "%i"% rect.get_width(),fontsize=13 )

plt.title('Sectors of Companies',fontsize=14, weight='bold')
plt.xlabel('Number of Companies Registered',fontsize=14)
plt.ylabel('Sectors',fontsize=14)
plt.show()

# %% [markdown]
# Heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
data.plot.line()
# Out:
# <AxesSubplot:>

# %%
plt.scatter(data.index,data['authorized_capital'])
plt.show()

# %%
plt.scatter(data.index,data['paidup_capital'])
plt.show()
